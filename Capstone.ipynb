# %% [markdown]
# COURSESRA CAPSTONE PROJECT

# %% [markdown]
# AUTHOR: RAHUL M

# %% [markdown]
# This notebook is for Coursera Capstone project

# %%
Import pandas as pd
Import numpy as np

# %%
print("Hello Capstone Project")
# Out:
# Hello Capstone Project
